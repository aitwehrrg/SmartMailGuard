# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv('final_combined.csv')

# %%
df
# Out:
#                                                   email     category
# 0     Congratulations! You've won a $1000 Walmart gi...         spam
# 1             Join us for a special event this weekend!       social
# 2       Limited time offer: 50% off your next purchase!  promotional
# 3        Hey, just checking in to see how you're doing.     personal
# 4              Your bank statement is ready for review.      finance
# ...                                                 ...          ...
# 2998  Please confirm your email address to continue ...    important
# 2999  Your scheduled payment is due in 2 days. Check...    important
# 3000  Your account requires immediate attention. Ple...    important
# 3001  Your recent purchase receipt is available. Che...      finance
# 3002      I saw this article and thought you'd love it!     personal
#
# [3003 rows x 2 columns]

# %%
X = df['email'].astype(str) 
y = df['category']

# %%
vectorizer = TfidfVectorizer(max_features = 1500) 
X_transformed = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)  
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_train_pred = rf_classifier.predict(X_train)

print("Accuracy:", accuracy_score(y_train, y_train_pred))
print("Classification Report:\n", classification_report(y_train, y_train_pred))
# Out:
# Accuracy: 0.9987510407993339
# Classification Report:
#                precision    recall  f1-score   support
#
#      finance       1.00      1.00      1.00        12
#    important       1.00      0.92      0.96        12
#     personal       1.00      1.00      1.00        11
#  promotional       1.00      1.00      1.00        11
#       social       1.00      1.00      1.00        11
#         spam       1.00      0.80      0.89        10
#      finance       1.00      1.00      1.00       399
#    important       1.00      1.00      1.00       450
#     personal       1.00      1.00      1.00       304
#  promotional       1.00      1.00      1.00       420
#       social       1.00      1.00      1.00       403
#         spam       0.99      1.00      1.00       359
#
#     accuracy                           1.00      2402
#    macro avg       1.00      0.98      0.99      2402
# weighted avg       1.00      1.00      1.00      2402

# %%
y_pred = rf_classifier.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8419301164725458
# Classification Report:
#                precision    recall  f1-score   support
#
#      finance       1.00      0.33      0.50         3
#    important       1.00      0.25      0.40         4
#     personal       1.00      0.50      0.67         4
#  promotional       0.00      0.00      0.00         4
#       social       1.00      0.67      0.80         3
#         spam       1.00      0.50      0.67         4
#      finance       0.90      0.82      0.86       101
#    important       0.77      0.93      0.84       126
#     personal       0.82      0.87      0.84        61
#  promotional       0.82      0.89      0.86        93
#       social       0.86      0.74      0.80       111
#         spam       0.91      0.92      0.91        87
#
#     accuracy                           0.84       601
#    macro avg       0.84      0.62      0.68       601
# weighted avg       0.84      0.84      0.84       601
# C:\Users\Kevin Shah\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kevin Shah\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Kevin Shah\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
